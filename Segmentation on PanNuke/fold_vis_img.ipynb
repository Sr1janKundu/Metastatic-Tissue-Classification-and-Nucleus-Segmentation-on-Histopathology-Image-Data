# %%
import os
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

# %%
#path = os.getcwd()
path = 'D:\\dissertation ideas\\PanNuke\\fold_3\\Fold 3'

# %%
images_path = os.path.join(path, 'images', 'fold3')
os.listdir(images_path)
# Out:
# ['images.npy', 'types.npy']

# %%
img_path = os.path.join(images_path, os.listdir(images_path)[0])
typ_path = os.path.join(images_path, os.listdir(images_path)[1])

# %%
tissues = np.load(img_path)

# %%
tissues.dtype
# Out:
# dtype('float64')

# %%
tissues.shape
# Out:
# (2722, 256, 256, 3)

# %%
plt.imshow(np.uint8(tissues[9]), cmap='gray')
plt.show()

# %%
new_img_save_path_f3 = 'E:\\Dissertation\\PanNuke\\Data\\fold3\\images'

# %%
j = 0 
for i in tissues:
    im = Image.fromarray(np.uint8(i))
    im.save(f'{new_img_save_path_f3}\\{j}.png')
    j += 1
